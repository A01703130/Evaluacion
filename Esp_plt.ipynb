# %% [markdown]
# <a href="https://colab.research.google.com/github/A01703130/Evaluacion/blob/main/Esp_plt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Carga desde un archivo .xlsx sin indice
esp= pd.read_csv('Girona-limpio.csv')
# Out:
# <ipython-input-5-6cd2a1848281>:2: DtypeWarning: Columns (0,2,22,41,45,46,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   esp= pd.read_csv('Girona-limpio.csv')

# %%
#Verificamos información del DataFrame
esp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19656 entries, 0 to 19655
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    19656 non-null  object
#  1   listing_url                                   19656 non-null  object
#  2   scrape_id                                     19656 non-null  object
#  3   last_scraped                                  19656 non-null  object
#  4   source                                        19656 non-null  object
#  5   name                                          19656 non-null  object
#  6   description                                   19656 non-null  object
#  7   neighborhood_overview                         19656 non-null  object
#  8   picture_url                                   19656 non-null  object
# ...

# %%
#Imprimo los primeros 5 registro del dataframe
esp.head()
# Out:
#   Unnamed: 0                           listing_url         scrape_id  \
# 0          0    https://www.airbnb.com/rooms/14551  20230300000000.0
# 1          1  https://www.airbnb.com/rooms/1205757  20230300000000.0
# 2          2  https://www.airbnb.com/rooms/1212820  20230300000000.0
# 3          3   https://www.airbnb.com/rooms/751638  20230300000000.0
# 4          4    https://www.airbnb.com/rooms/41342  20230300000000.0
#
#   last_scraped           source                                      name  \
# 0   31/03/2023      city scrape  Cozy & Colorful by Nature (Private Room)
# 1   31/03/2023      city scrape       HabitaciÃ³n doble + baÃ±o y terraza
# 2   01/04/2023      city scrape       Apartment port de rei stunning wiew
# 3   31/03/2023      city scrape       Room Limon - Casa Pati de lÂ´Albera
# 4   01/04/2023  previous scrape         Beachfront Tamariua (Costa Brava)
#
#                                          description  \
# ...

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(esp['host_identity_verified'])
table1
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      17276    0.878917         0.878962
# 1                      f       2261    0.115028         0.993996
# 2           Sin registro        117    0.005952         0.999949
# 3                $315.00          1    0.000051         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>100]
Filtro
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      17276    0.878917         0.878962
# 1                      f       2261    0.115028         0.993996
# 2           Sin registro        117    0.005952         0.999949

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_identity_verified')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           17276    0.878917         0.878962
# f                            2261    0.115028         0.993996
# Sin registro                  117    0.005952         0.999949

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(esp['host_acceptance_rate'])
table2
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       7477    0.380393         0.380412
# 1                   99%       2221    0.112993         0.493411
# 2          Sin registro       1153    0.058659         0.552073
# 3                   98%       1049    0.053368         0.605444
# 4                   96%        753    0.038309         0.643755
# ..                  ...        ...         ...              ...
# 88              3.20558          1    0.000051         0.999796
# 89                   8%          1    0.000051         0.999847
# 90                   7%          1    0.000051         0.999898
# 91                  21%          1    0.000051         0.999949
# 92                  23%          1    0.000051         1.000000
#
# [93 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table2[table2['frequency']>500]
Filtro
# Out:
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                 100%       7477    0.380393         0.380412
# 1                  99%       2221    0.112993         0.493411
# 2         Sin registro       1153    0.058659         0.552073
# 3                  98%       1049    0.053368         0.605444
# 4                  96%        753    0.038309         0.643755
# 5                  97%        735    0.037393         0.681150
# 6                  91%        518    0.026353         0.707504

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_acceptance_rate')
Filtro_index
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                       7477    0.380393         0.380412
# 99%                        2221    0.112993         0.493411
# Sin registro               1153    0.058659         0.552073
# 98%                        1049    0.053368         0.605444
# 96%                         753    0.038309         0.643755
# 97%                         735    0.037393         0.681150
# 91%                         518    0.026353         0.707504

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(esp['host_response_time'])
table3
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      12261    0.623779         0.623811
# 1  within a few hours       2699    0.137312         0.761129
# 2        within a day       2188    0.111315         0.872450
# 3        Sin registro       2089    0.106278         0.978733
# 4  a few days or more        418    0.021266         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table3[table3['frequency']>130]
Filtro
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      12261    0.623779         0.623811
# 1  within a few hours       2699    0.137312         0.761129
# 2        within a day       2188    0.111315         0.872450
# 3        Sin registro       2089    0.106278         0.978733
# 4  a few days or more        418    0.021266         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_response_time')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour          12261    0.623779         0.623811
# within a few hours       2699    0.137312         0.761129
# within a day             2188    0.111315         0.872450
# Sin registro             2089    0.106278         0.978733
# a few days or more        418    0.021266         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(esp['property_type'])
table4
# Out:
#                    property_type  frequency  percentage  cumulative_perc
# 0             Entire rental unit       9339    0.475122         0.475146
# 1                    Entire home       3703    0.188390         0.663546
# 2                   Entire villa       1714    0.087200         0.750750
# 3                   Entire condo       1400    0.071225         0.821979
# 4                 Entire cottage        549    0.027930         0.849911
# ..                           ...        ...         ...              ...
# 73  Private room in earthen home          1    0.000051         0.999796
# 74           Private room in hut          1    0.000051         0.999847
# 75                          60.0          1    0.000051         0.999898
# 76         Private room in cabin          1    0.000051         0.999949
# 77     Private room in treehouse          1    0.000051         1.000000
#
# [78 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table4[table4['frequency']>450]
Filtro
# Out:
#         property_type  frequency  percentage  cumulative_perc
# 0  Entire rental unit       9339    0.475122         0.475146
# 1         Entire home       3703    0.188390         0.663546
# 2        Entire villa       1714    0.087200         0.750750
# 3        Entire condo       1400    0.071225         0.821979
# 4      Entire cottage        549    0.027930         0.849911
# 5    Entire townhouse        453    0.023046         0.872959

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('property_type')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit       9339    0.475122         0.475146
# Entire home              3703    0.188390         0.663546
# Entire villa             1714    0.087200         0.750750
# Entire condo             1400    0.071225         0.821979
# Entire cottage            549    0.027930         0.849911
# Entire townhouse          453    0.023046         0.872959

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
esp.number_of_reviews=esp.number_of_reviews.astype(str)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(esp['number_of_reviews'])
table5
# Out:
#     number_of_reviews  frequency  percentage  cumulative_perc
# 0                 0.0       5227    0.265924         0.265924
# 1                 1.0       2075    0.105566         0.371490
# 2                 2.0       1443    0.073413         0.444902
# 3                 3.0       1154    0.058710         0.503612
# 4                 4.0        937    0.047670         0.551282
# ..                ...        ...         ...              ...
# 278             289.0          1    0.000051         0.999796
# 279             282.0          1    0.000051         0.999847
# 280             432.0          1    0.000051         0.999898
# 281             242.0          1    0.000051         0.999949
# 282             182.0          1    0.000051         1.000000
#
# [283 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table5[table5['frequency']>650]
Filtro
# Out:
#   number_of_reviews  frequency  percentage  cumulative_perc
# 0               0.0       5227    0.265924         0.265924
# 1               1.0       2075    0.105566         0.371490
# 2               2.0       1443    0.073413         0.444902
# 3               3.0       1154    0.058710         0.503612
# 4               4.0        937    0.047670         0.551282
# 5               5.0        688    0.035002         0.586284

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('number_of_reviews')
Filtro_index
# Out:
#                    frequency  percentage  cumulative_perc
# number_of_reviews
# 0.0                     5227    0.265924         0.265924
# 1.0                     2075    0.105566         0.371490
# 2.0                     1443    0.073413         0.444902
# 3.0                     1154    0.058710         0.503612
# 4.0                      937    0.047670         0.551282
# 5.0                      688    0.035002         0.586284

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
