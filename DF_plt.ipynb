# %% [markdown]
# <a href="https://colab.research.google.com/github/A01703130/Evaluacion/blob/main/DF_plt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_csv('DF-limpio-2.csv')
# Out:
# <ipython-input-4-cd5d91d55e19>:2: DtypeWarning: Columns (2,22,41,45,46,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('DF-limpio-2.csv')

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24225 entries, 0 to 24224
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    24224 non-null  float64
#  1   listing_url                                   24225 non-null  object
#  2   scrape_id                                     24225 non-null  object
#  3   last_scraped                                  24225 non-null  object
#  4   source                                        24225 non-null  object
#  5   name                                          24225 non-null  object
#  6   description                                   24225 non-null  object
#  7   neighborhood_overview                         24225 non-null  object
#  8   picture_url                                   24225 non-null  object
# ...

# %%
#Imprimo los primeros 5 registro del dataframe
df.head()
# Out:
#    Unnamed: 0                           listing_url       scrape_id  \
# 0         0.0  https://www.airbnb.com/rooms/2056638  20230329041210
# 1         1.0  https://www.airbnb.com/rooms/2072354  20230329041210
# 2         2.0   https://www.airbnb.com/rooms/696037  20230329041210
# 3         3.0    https://www.airbnb.com/rooms/35797  20230329041210
# 4         4.0    https://www.airbnb.com/rooms/44616  20230329041210
#
#   last_scraped       source  \
# 0   2023-03-30  city scrape
# 1   2023-03-30  city scrape
# 2   2023-03-29  city scrape
# 3   2023-03-29  city scrape
# 4   2023-03-30  city scrape
#
#                                                 name  \
# 0                 Amplio y luminoso loft en Coyoacán
# 1                 Coyoacan Historic Studio Apartment
# 2  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3                                        Villa Dante
# 4                                  CONDESA HAUS  B&B
#
# ...

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df['host_identity_verified'])
table1
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      22300    0.920537         0.920575
# 1                      f       1923    0.079381         0.999959
# 2                $908.00          1    0.000041         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      22300    0.920537         0.920575
# 1                      f       1923    0.079381         0.999959

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_identity_verified')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           22300    0.920537         0.920575
# f                            1923    0.079381         0.999959

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(df['host_acceptance_rate'])
table2
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%      11616    0.479505         0.479524
# 1                   99%       2704    0.111620         0.591149
# 2          Sin registro       2043    0.084334         0.675487
# 3                   98%       1031    0.042559         0.718048
# 4                   97%        711    0.029350         0.747399
# ..                  ...        ...         ...              ...
# 87            -99.15667          1    0.000041         0.999835
# 88                   9%          1    0.000041         0.999876
# 89                  13%          1    0.000041         0.999917
# 90                  18%          1    0.000041         0.999959
# 91                  30%          1    0.000041         1.000000
#
# [92 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table2[table2['frequency']>700]
Filtro
# Out:
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                 100%      11616    0.479505         0.479524
# 1                  99%       2704    0.111620         0.591149
# 2         Sin registro       2043    0.084334         0.675487
# 3                  98%       1031    0.042559         0.718048
# 4                  97%        711    0.029350         0.747399
# 5                   0%        701    0.028937         0.776338

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_acceptance_rate')
Filtro_index
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                      11616    0.479505         0.479524
# 99%                        2704    0.111620         0.591149
# Sin registro               2043    0.084334         0.675487
# 98%                        1031    0.042559         0.718048
# 97%                         711    0.029350         0.747399
# 0%                          701    0.028937         0.776338

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(df['host_response_time'])
table3
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      16996    0.701589         0.701618
# 1        Sin registro       3092    0.127637         0.829260
# 2  within a few hours       1966    0.081156         0.910419
# 3        within a day       1450    0.059856         0.970277
# 4  a few days or more        720    0.029721         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table3[table3['frequency']>130]
Filtro
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      16996    0.701589         0.701618
# 1        Sin registro       3092    0.127637         0.829260
# 2  within a few hours       1966    0.081156         0.910419
# 3        within a day       1450    0.059856         0.970277
# 4  a few days or more        720    0.029721         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_response_time')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour          16996    0.701589         0.701618
# Sin registro             3092    0.127637         0.829260
# within a few hours       1966    0.081156         0.910419
# within a day             1450    0.059856         0.970277
# a few days or more        720    0.029721         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(df['property_type'])
table4
# Out:
#                    property_type  frequency  percentage  cumulative_perc
# 0             Entire rental unit       8144    0.336182         0.336196
# 1                   Entire condo       3363    0.138824         0.475025
# 2    Private room in rental unit       2860    0.118060         0.593089
# 3           Private room in home       2009    0.082931         0.676024
# 4                    Entire loft       1584    0.065387         0.741413
# ..                           ...        ...         ...              ...
# 88          Private room in barn          1    0.000041         0.999835
# 89  Private room in earthen home          1    0.000041         0.999876
# 90      Shared room in tiny home          1    0.000041         0.999917
# 91         Private room in tower          1    0.000041         0.999959
# 92           Shared room in tent          1    0.000041         1.000000
#
# [93 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table4[table4['frequency']>1000]
Filtro
# Out:
#                  property_type  frequency  percentage  cumulative_perc
# 0           Entire rental unit       8144    0.336182         0.336196
# 1                 Entire condo       3363    0.138824         0.475025
# 2  Private room in rental unit       2860    0.118060         0.593089
# 3         Private room in home       2009    0.082931         0.676024
# 4                  Entire loft       1584    0.065387         0.741413
# 5    Entire serviced apartment       1067    0.044045         0.785461

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('property_type')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                8144    0.336182         0.336196
# Entire condo                      3363    0.138824         0.475025
# Private room in rental unit       2860    0.118060         0.593089
# Private room in home              2009    0.082931         0.676024
# Entire loft                       1584    0.065387         0.741413
# Entire serviced apartment         1067    0.044045         0.785461

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
df.number_of_reviews=df.number_of_reviews.astype(str)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(df['number_of_reviews'])
table5
# Out:
#     number_of_reviews  frequency  percentage  cumulative_perc
# 0                 0.0       3596    0.148442         0.148442
# 1                 1.0       1778    0.073395         0.221837
# 2                 2.0       1209    0.049907         0.271744
# 3                 3.0       1014    0.041858         0.313602
# 4                 4.0        769    0.031744         0.345346
# ..                ...        ...         ...              ...
# 455             344.0          1    0.000041         0.999835
# 456             293.0          1    0.000041         0.999876
# 457             367.0          1    0.000041         0.999917
# 458             379.0          1    0.000041         0.999959
# 459             535.0          1    0.000041         1.000000
#
# [460 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table5[table5['frequency']>600]
Filtro
# Out:
#   number_of_reviews  frequency  percentage  cumulative_perc
# 0               0.0       3596    0.148442         0.148442
# 1               1.0       1778    0.073395         0.221837
# 2               2.0       1209    0.049907         0.271744
# 3               3.0       1014    0.041858         0.313602
# 4               4.0        769    0.031744         0.345346
# 5               5.0        628    0.025924         0.371269

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('number_of_reviews')
Filtro_index
# Out:
#                    frequency  percentage  cumulative_perc
# number_of_reviews
# 0.0                     3596    0.148442         0.148442
# 1.0                     1778    0.073395         0.221837
# 2.0                     1209    0.049907         0.271744
# 3.0                     1014    0.041858         0.313602
# 4.0                      769    0.031744         0.345346
# 5.0                      628    0.025924         0.371269

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
